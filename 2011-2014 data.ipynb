# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

csvdata2011= "2011 Stack Overflow Survey Results.csv"
csvdata2012= "2012 Stack Overflow Survey Results.csv"
csvdata2013= "2013 Stack Overflow Survey Responses.csv"
csvdata2014= "2014 Stack Overflow Survey Responses.csv"


data2014 = pd.read_csv(csvdata2014)
data2013 = pd.read_csv(csvdata2013)
data2012 = pd.read_csv(csvdata2012)
data2011 = pd.read_csv(csvdata2011)
# Out:
# C:\Users\Dan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (46,48,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data2011
# Out:
#      What Country or Region do you live in?  \
# 0                                  Response
# 1                                    Africa
# 2                              Other Europe
# 3                                     India
# 4                                   Germany
# ...                                     ...
# 2809               United States of America
# 2810               United States of America
# 2811                             Other Asia
# 2812               United States of America
# 2813               United States of America
#
#      Which US State or Territory do you live in? How old are you?  \
# 0                                       Response         Response
# 1                                            NaN             < 20
# 2                                            NaN            25-29
# 3                                            NaN            25-29
# 4                                            NaN             < 20
# ...

# %%
data2011 = data2011[['What Country or Region do you live in?',
                     'How old are you?',
                     'Including bonus, what is your annual compensation in USD?',
                     'Which languages are you proficient in?',
                     'Unnamed: 31',
                     'Unnamed: 32',
                     'Unnamed: 33',
                     'Unnamed: 34',
                     'Unnamed: 35',
                     'Unnamed: 36',
                     'Unnamed: 37',
                     'Unnamed: 38',
                     'Unnamed: 39',
                     'Unnamed: 40',
                     'Unnamed: 41',
                     'Unnamed: 42']]
data2011
# Out:
#      What Country or Region do you live in? How old are you?  \
# 0                                  Response         Response
# 1                                    Africa             < 20
# 2                              Other Europe            25-29
# 3                                     India            25-29
# 4                                   Germany             < 20
# ...                                     ...              ...
# 2809               United States of America            40-50
# 2810               United States of America            20-24
# 2811                             Other Asia            20-24
# 2812               United States of America            25-29
# 2813               United States of America            51-60
#
#      Including bonus, what is your annual compensation in USD?  \
# 0                                              Response
# 1                                  Student / Unemployed
# ...

# %%
data2011.columns = data2011.iloc[0]
data2011 = data2011.drop(0)

# %%
cols = []
count = 1
for column in data2011.columns:
    if column == 'Response':
        cols.append(f'Response_{count}')
        count+=1
        continue
    cols.append(column)
data2011.columns = cols

data2011
# Out:
#                     Response_1 Response_2            Response_3  Java  \
# 1                       Africa       < 20  Student / Unemployed   NaN
# 2                 Other Europe      25-29                   NaN  Java
# 3                        India      25-29                   NaN  Java
# 4                      Germany       < 20  Student / Unemployed  Java
# 5                   Other Asia      35-39    $80,000 - $100,000  Java
# ...                        ...        ...                   ...   ...
# 2809  United States of America      40-50     $40,000 - $60,000   NaN
# 2810  United States of America      20-24     $60,000 - $80,000   NaN
# 2811                Other Asia      20-24              <$20,000   NaN
# 2812  United States of America      25-29     $40,000 - $60,000   NaN
# 2813  United States of America      51-60     $60,000 - $80,000   NaN
#
#       JavaScript  CSS  PHP  Python Ruby  SQL   C#  C++    C  Perl None  \
# ...

# %%
data2011 = data2011.rename(columns={"Response_1": "Country", "Response_2": "Age", "Response_3": "Income"})
data2011
# Out:
#                        Country    Age                Income  Java  JavaScript  \
# 1                       Africa   < 20  Student / Unemployed   NaN  JavaScript
# 2                 Other Europe  25-29                   NaN  Java         NaN
# 3                        India  25-29                   NaN  Java  JavaScript
# 4                      Germany   < 20  Student / Unemployed  Java         NaN
# 5                   Other Asia  35-39    $80,000 - $100,000  Java  JavaScript
# ...                        ...    ...                   ...   ...         ...
# 2809  United States of America  40-50     $40,000 - $60,000   NaN  JavaScript
# 2810  United States of America  20-24     $60,000 - $80,000   NaN  JavaScript
# 2811                Other Asia  20-24              <$20,000   NaN  JavaScript
# 2812  United States of America  25-29     $40,000 - $60,000   NaN  JavaScript
# 2813  United States of America  51-60     $60,000 - $80,000   NaN         NaN
#
# ...

# %%
data2011.columns
# Out:
# Index(['Country', 'Age', 'Income', 'Java', 'JavaScript', 'CSS', 'PHP',
#        'Python', 'Ruby', 'SQL', 'C#', 'C++', 'C', 'Perl', 'None',
#        'other (please specify)'],
#       dtype='object')

# %%
languages = [ 'Java', 'JavaScript', 'CSS', 'PHP',
       'Python', 'Ruby', 'SQL', 'C#', 'C++', 'C', 'Perl', 'None']
for lang in languages:
    data2011[lang] = (data2011[lang] == lang)

# %%
data2011.head()
# Out:
#         Country    Age                Income   Java  JavaScript    CSS    PHP  \
# 1        Africa   < 20  Student / Unemployed  False        True  False  False
# 2  Other Europe  25-29                   NaN   True       False  False  False
# 3         India  25-29                   NaN   True        True  False  False
# 4       Germany   < 20  Student / Unemployed   True       False  False  False
# 5    Other Asia  35-39    $80,000 - $100,000   True        True   True   True
#
#    Python   Ruby    SQL     C#    C++      C   Perl   None  \
# 1   False  False  False  False  False  False  False  False
# 2   False  False   True  False  False   True  False  False
# 3   False  False   True  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False
# 5   False  False   True  False   True   True   True  False
#
#   other (please specify)
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                Haskell
# ...

# %%
data2011["Income"].value_counts()
# Out:
# $40,000 - $60,000       415
# $60,000 - $80,000       413
# $20,000 - $40,000       318
# $80,000 - $100,000      292
# <$20,000                283
# $100,000 - $120,000     222
# Student / Unemployed    215
# >$140,000               110
# $120,000 - $140,000      97
# Name: Income, dtype: int64

# %%
list(data2012.columns)
# Out:
# ['What Country or Region do you live in?',
#  'Which US State or Territory do you live in?',
#  'How old are you?',
#  'How many years of IT/Programming experience do you have?',
#  'How would you best describe the industry you currently work in?',
#  'Which best describes the size of your company?',
#  'Which of the following best describes your occupation?',
#  'What is your involvement in purchasing products or services for the company you work for? (You can choose more than one)',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'What types of purchases are you involved in?',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'What is your budget for outside expenditures (hardware, software, consulting, etc) for 2011?',
#  'What type of project are you developing?',
#  'Which languages are you proficient in?',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
# ...

# %%
data2012 = data2012[['What Country or Region do you live in?',
                     'How old are you?',
                     'Including bonus, what is your annual compensation in USD?',
                     'Which languages are you proficient in?',
                     'Unnamed: 23',
                     'Unnamed: 24',
                     'Unnamed: 25',
                     'Unnamed: 26',
                     'Unnamed: 27',
                     'Unnamed: 28',
                     'Unnamed: 29',
                     'Unnamed: 30',
                     'Unnamed: 31',
                     'Unnamed: 32',
                     'Unnamed: 33',
                     'Unnamed: 34',
                     'Unnamed: 35',
                     'Unnamed: 36']]
data2012
# Out:
#      What Country or Region do you live in? How old are you?  \
# 0                                  Response         Response
# 1                                     India            20-24
# 2                                   Germany            25-29
# 3                            United Kingdom            20-24
# 4                                    France            20-24
# ...                                     ...              ...
# 6239                                 Russia            20-24
# 6240                                 Africa            20-24
# 6241               United States of America            20-24
# 6242                           Other Europe            40-50
# 6243               United States of America            30-34
#
#      Including bonus, what is your annual compensation in USD?  \
# 0                                              Response
# 1                                              <$20,000
# ...

# %%
data2012.columns = data2012.iloc[0]
data2012 = data2012.drop(0)

# %%
cols = []
count = 1
for column in data2012.columns:
    if column == 'Response':
        cols.append(f'Response_{count}')
        count+=1
        continue
    cols.append(column)
data2012.columns = cols

data2012
# Out:
#                     Response_1 Response_2            Response_3  Java  \
# 1                        India      20-24              <$20,000  Java
# 2                      Germany      25-29     $20,000 - $40,000   NaN
# 3               United Kingdom      20-24     $20,000 - $40,000   NaN
# 4                       France      20-24     $20,000 - $40,000  Java
# 5     United States of America       < 20  Student / Unemployed  Java
# ...                        ...        ...                   ...   ...
# 6239                    Russia      20-24  Student / Unemployed  Java
# 6240                    Africa      20-24                   NaN   NaN
# 6241  United States of America      20-24     $40,000 - $60,000  Java
# 6242              Other Europe      40-50    $80,000 - $100,000   NaN
# 6243  United States of America      30-34    $80,000 - $100,000   NaN
#
#       JavaScript  CSS  PHP Python  Objective-C Ruby  SQL   C#  C++    C Perl  \
# ...

# %%
data2012 = data2012.rename(columns={"Response_1": "Country", "Response_2": "Age", "Response_3": "Income"})
data2012
# Out:
#                        Country    Age                Income  Java  JavaScript  \
# 1                        India  20-24              <$20,000  Java  JavaScript
# 2                      Germany  25-29     $20,000 - $40,000   NaN  JavaScript
# 3               United Kingdom  20-24     $20,000 - $40,000   NaN         NaN
# 4                       France  20-24     $20,000 - $40,000  Java         NaN
# 5     United States of America   < 20  Student / Unemployed  Java         NaN
# ...                        ...    ...                   ...   ...         ...
# 6239                    Russia  20-24  Student / Unemployed  Java         NaN
# 6240                    Africa  20-24                   NaN   NaN         NaN
# 6241  United States of America  20-24     $40,000 - $60,000  Java         NaN
# 6242              Other Europe  40-50    $80,000 - $100,000   NaN         NaN
# 6243  United States of America  30-34    $80,000 - $100,000   NaN         NaN
#
# ...

# %%
list(data2012.columns)
# Out:
# ['Country',
#  'Age',
#  'Income',
#  'Java',
#  'JavaScript',
#  'CSS',
#  'PHP',
#  'Python',
#  'Objective-C',
#  'Ruby',
#  'SQL',
#  'C#',
#  'C++',
#  'C',
#  'Perl',
#  'HTML5',
#  'None',
#  'Other (please specify)']

# %%
languages = [ 'Java',
 'JavaScript',
 'CSS',
 'PHP',
 'Python',
 'Objective-C',
 'Ruby',
 'SQL',
 'C#',
 'C++',
 'C',
 'Perl',
 'HTML5',
 'None']
for lang in languages:
    data2012[lang] = (data2012[lang] == lang)

# %%
data2012
# Out:
#                        Country    Age                Income   Java  \
# 1                        India  20-24              <$20,000   True
# 2                      Germany  25-29     $20,000 - $40,000  False
# 3               United Kingdom  20-24     $20,000 - $40,000  False
# 4                       France  20-24     $20,000 - $40,000   True
# 5     United States of America   < 20  Student / Unemployed   True
# ...                        ...    ...                   ...    ...
# 6239                    Russia  20-24  Student / Unemployed   True
# 6240                    Africa  20-24                   NaN  False
# 6241  United States of America  20-24     $40,000 - $60,000   True
# 6242              Other Europe  40-50    $80,000 - $100,000  False
# 6243  United States of America  30-34    $80,000 - $100,000  False
#
#       JavaScript    CSS    PHP  Python  Objective-C   Ruby    SQL     C#  \
# 1           True  False  False   False        False  False   True  False
# ...

# %%
data2013
# Out:
#      What Country or Region do you live in?  \
# 0                                  Response
# 1                            United Kingdom
# 2                  United States of America
# 3                  United States of America
# 4                                   Germany
# ...                                     ...
# 9738               United States of America
# 9739               United States of America
# 9740                         United Kingdom
# 9741                           Other Europe
# 9742                         United Kingdom
#
#      Which US State or Territory do you live in? How old are you?  \
# 0                                       Response         Response
# 1                                            NaN            35-39
# 2                                         Oregon            25-29
# 3                                      Wisconsin            51-60
# 4                                            NaN              NaN
# ...

# %%
list(data2013.columns)
# Out:
# ['What Country or Region do you live in?',
#  'Which US State or Territory do you live in?',
#  'How old are you?',
#  'How many years of IT/Programming experience do you have?',
#  'How would you best describe the industry you currently work in?',
#  'How many people work for your company?',
#  'Which of the following best describes your occupation?',
#  'Including yourself, how many developers are employed at your company?',
#  'How large is the team that you work on?',
#  'What other departments / roles do you interact with regularly?',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'If your company has a native mobile app, what platforms do you support?',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'If you make a software product, how does your company make money? (You can choose more than one)',
# ...

# %%
data2013 = data2013[['What Country or Region do you live in?',
                     'How old are you?',
                     'Including bonus, what is your annual compensation in USD?',
                     'Which of the following languages or technologies have you used significantly in the past year?',
                     'Unnamed: 57',
                     'Unnamed: 58',
                     'Unnamed: 59',
                     'Unnamed: 60',
                     'Unnamed: 61',
                     'Unnamed: 62',
                     'Unnamed: 63',
                     'Unnamed: 64',
                     'Unnamed: 65',
                     'Unnamed: 66',
                     'Unnamed: 67',
                     'Unnamed: 68',
                     'Unnamed: 69']]
data2013
# Out:
#      What Country or Region do you live in? How old are you?  \
# 0                                  Response         Response
# 1                            United Kingdom            35-39
# 2                  United States of America            25-29
# 3                  United States of America            51-60
# 4                                   Germany              NaN
# ...                                     ...              ...
# 9738               United States of America            30-34
# 9739               United States of America            20-24
# 9740                         United Kingdom            20-24
# 9741                           Other Europe            30-34
# 9742                         United Kingdom            25-29
#
#      Including bonus, what is your annual compensation in USD?  \
# 0                                              Response
# 1                                    $80,000 - $100,000
# ...

# %%
data2013.columns = data2013.iloc[0]
data2013 = data2013.drop(0)

# %%
cols = []
count = 1
for column in data2013.columns:
    if column == 'Response':
        cols.append(f'Response_{count}')
        count+=1
        continue
    cols.append(column)
data2013.columns = cols

# %%
data2013 = data2013.rename(columns={"Response_1": "Country", "Response_2": "Age", "Response_3": "Income"})

# %%
data2013
# Out:
#                        Country    Age                Income    C  C++   C#  \
# 1               United Kingdom  35-39    $80,000 - $100,000  NaN  NaN  NaN
# 2     United States of America  25-29     $20,000 - $40,000  NaN  NaN   C#
# 3     United States of America  51-60   $120,000 - $140,000  NaN  NaN   C#
# 4                      Germany    NaN                   NaN  NaN  NaN  NaN
# 5     United States of America  35-39                   NaN  NaN  NaN  NaN
# ...                        ...    ...                   ...  ...  ...  ...
# 9738  United States of America  30-34    $80,000 - $100,000    C  C++  NaN
# 9739  United States of America  20-24        Rather not say  NaN  NaN   C#
# 9740            United Kingdom  20-24  Student / Unemployed  NaN  C++  NaN
# 9741              Other Europe  30-34     $60,000 - $80,000  NaN  NaN   C#
# 9742            United Kingdom  25-29   $100,000 - $120,000  NaN  NaN   C#
#
# ...

# %%
languages = [ 'C',
 'C++',
 'C#',
 'Java',
 'JavaScript',
 'jQuery',
 'JQuery',
 'Node.js',
 'Objective-C',
 'PHP',
 'Python',
 'Ruby',
 'SQL',]
for lang in languages:
    data2013[lang] = (data2013[lang] == lang)

# %%
data2013
# Out:
#                        Country    Age                Income      C    C++  \
# 1               United Kingdom  35-39    $80,000 - $100,000  False  False
# 2     United States of America  25-29     $20,000 - $40,000  False  False
# 3     United States of America  51-60   $120,000 - $140,000  False  False
# 4                      Germany    NaN                   NaN  False  False
# 5     United States of America  35-39                   NaN  False  False
# ...                        ...    ...                   ...    ...    ...
# 9738  United States of America  30-34    $80,000 - $100,000   True   True
# 9739  United States of America  20-24        Rather not say  False  False
# 9740            United Kingdom  20-24  Student / Unemployed  False   True
# 9741              Other Europe  30-34     $60,000 - $80,000  False  False
# 9742            United Kingdom  25-29   $100,000 - $120,000  False  False
#
#          C#   Java  JavaScript  jQuery  JQuery  Node.js  Objective-C    PHP  \
# ...

# %%
data2014
# Out:
#      What Country do you live in?              Unnamed: 1  \
# 0                        Response  Other (please specify)
# 1                           India                     NaN
# 2                        Thailand                     NaN
# 3                            Iran                     NaN
# 4                         Ukraine                     NaN
# ...                           ...                     ...
# 7639                United States                     NaN
# 7640                       Canada                     NaN
# 7641                United States                     NaN
# 7642                United States                     NaN
# 7643                United States                     NaN
#
#      Which US State or Territory do you live in? How old are you?  \
# 0                                       Response         Response
# 1                                            NaN            30-34
# 2                                            NaN            20-24
# ...

# %%
list(data2014.columns)
# Out:
# ['What Country do you live in?',
#  'Unnamed: 1',
#  'Which US State or Territory do you live in?',
#  'How old are you?',
#  'What is your gender?',
#  'How many years of IT/Programming experience do you have?',
#  'Which of the following best describes your occupation?',
#  'Including bonus, what is your annual compensation in USD?',
#  'How would you best describe the industry you currently work in?',
#  'How many developers are employed at your company?',
#  'Do you work remotely?',
#  'Do you enjoy working remotely?',
#  'Where do you work remotely most of the time?',
#  'If your company has a native mobile app, what platforms do you support?',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'In an average week, how do you spend your time at work?',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
# ...

# %%
data2014 = data2014[['What Country do you live in?', 'What Country do you live in?', 
                     'Including bonus, what is your annual compensation in USD?',
                     'Which of the following languages or technologies have you used significantly in the past year?',
                     'Unnamed: 43',
                     'Unnamed: 44',
                     'Unnamed: 45',
                     'Unnamed: 46',
                     'Unnamed: 47',
                     'Unnamed: 48',
                     'Unnamed: 49',
                     'Unnamed: 50',
                     'Unnamed: 51',
                     'Unnamed: 52',
                     'Unnamed: 53']]
data2014
# Out:
#      What Country do you live in? What Country do you live in?  \
# 0                        Response                     Response
# 1                           India                        India
# 2                        Thailand                     Thailand
# 3                            Iran                         Iran
# 4                         Ukraine                      Ukraine
# ...                           ...                          ...
# 7639                United States                United States
# 7640                       Canada                       Canada
# 7641                United States                United States
# 7642                United States                United States
# 7643                United States                United States
#
#      Including bonus, what is your annual compensation in USD?  \
# 0                                              Response
# 1                                     $20,000 - $40,000
# ...

# %%
data2014.columns = data2014.iloc[0]
data2014 = data2014.drop(0)

# %%
cols = []
count = 1
for column in data2014.columns:
    if column == 'Response':
        cols.append(f'Response_{count}')
        count+=1
        continue
    cols.append(column)
data2014.columns = cols

# %%
data2014 = data2014.rename(columns={"Response_1": "Country", "Response_2": "Age", "Response_3": "Income"})

# %%
data2014
# Out:
#             Country            Age                Income    C  C++   C#  Java  \
# 1             India          India     $20,000 - $40,000  NaN  NaN  NaN  Java
# 2          Thailand       Thailand  Student / Unemployed  NaN  NaN  NaN   NaN
# 3              Iran           Iran              <$20,000  NaN  NaN   C#   NaN
# 4           Ukraine        Ukraine  Student / Unemployed  NaN  C++  NaN   NaN
# 5             India          India        Rather not say  NaN  NaN  NaN  Java
# ...             ...            ...                   ...  ...  ...  ...   ...
# 7639  United States  United States             >$140,000    C  C++  NaN  Java
# 7640         Canada         Canada     $60,000 - $80,000  NaN  NaN   C#   NaN
# 7641  United States  United States   $100,000 - $120,000  NaN  NaN  NaN  Java
# 7642  United States  United States   $120,000 - $140,000  NaN  NaN   C#   NaN
# 7643  United States  United States  Student / Unemployed  NaN  NaN  NaN   NaN
#
# ...

# %%
list(data2014.columns)
# Out:
# ['Country',
#  'Age',
#  'Income',
#  'C',
#  'C++',
#  'C#',
#  'Java',
#  'JavaScript',
#  'Node.js',
#  'Objective-C',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'Other (please specify)']

# %%
languages = [ 'C',
 'C++',
 'C#',
 'Java',
 'JavaScript',
 'Node.js',
 'Objective-C',
 'PHP',
 'Python',
 'Ruby',
 'SQL',]
for lang in languages:
    data2014[lang] = (data2014[lang] == lang)

# %%
data2014
# Out:
#             Country            Age                Income      C    C++     C#  \
# 1             India          India     $20,000 - $40,000  False  False  False
# 2          Thailand       Thailand  Student / Unemployed  False  False  False
# 3              Iran           Iran              <$20,000  False  False   True
# 4           Ukraine        Ukraine  Student / Unemployed  False   True  False
# 5             India          India        Rather not say  False  False  False
# ...             ...            ...                   ...    ...    ...    ...
# 7639  United States  United States             >$140,000   True   True  False
# 7640         Canada         Canada     $60,000 - $80,000  False  False   True
# 7641  United States  United States   $100,000 - $120,000  False  False  False
# 7642  United States  United States   $120,000 - $140,000  False  False   True
# 7643  United States  United States  Student / Unemployed  False  False  False
#
# ...

# %%
data2011
# Out:
#                        Country    Age                Income   Java  \
# 1                       Africa   < 20  Student / Unemployed  False
# 2                 Other Europe  25-29                   NaN   True
# 3                        India  25-29                   NaN   True
# 4                      Germany   < 20  Student / Unemployed   True
# 5                   Other Asia  35-39    $80,000 - $100,000   True
# ...                        ...    ...                   ...    ...
# 2809  United States of America  40-50     $40,000 - $60,000  False
# 2810  United States of America  20-24     $60,000 - $80,000  False
# 2811                Other Asia  20-24              <$20,000  False
# 2812  United States of America  25-29     $40,000 - $60,000  False
# 2813  United States of America  51-60     $60,000 - $80,000  False
#
#       JavaScript    CSS    PHP  Python   Ruby    SQL     C#    C++      C  \
# 1           True  False  False   False  False  False  False  False  False
# ...

# %%
data2011['Year'] = "2011"

# %%
list(data2011.columns)
# Out:
# ['Country',
#  'Age',
#  'Income',
#  'Java',
#  'JavaScript',
#  'CSS',
#  'PHP',
#  'Python',
#  'Ruby',
#  'SQL',
#  'C#',
#  'C++',
#  'C',
#  'Perl',
#  'None',
#  'other (please specify)',
#  'Year']

# %%
data2011 = data2011[['Year','Country', 'Age', 'Income',
                     'Java', 'JavaScript', 'CSS', 'PHP',
                     'Python', 'Ruby', 'SQL', 'C#', 'C++',
                     'C', 'Perl', 'other (please specify)' ]]
data2011
# Out:
#       Year                   Country    Age                Income   Java  \
# 1     2011                    Africa   < 20  Student / Unemployed  False
# 2     2011              Other Europe  25-29                   NaN   True
# 3     2011                     India  25-29                   NaN   True
# 4     2011                   Germany   < 20  Student / Unemployed   True
# 5     2011                Other Asia  35-39    $80,000 - $100,000   True
# ...    ...                       ...    ...                   ...    ...
# 2809  2011  United States of America  40-50     $40,000 - $60,000  False
# 2810  2011  United States of America  20-24     $60,000 - $80,000  False
# 2811  2011                Other Asia  20-24              <$20,000  False
# 2812  2011  United States of America  25-29     $40,000 - $60,000  False
# 2813  2011  United States of America  51-60     $60,000 - $80,000  False
#
#       JavaScript    CSS    PHP  Python   Ruby    SQL     C#    C++      C  \
# ...

# %%
data2011.to_csv("data2011.csv", index=True, header=True)
data2012.to_csv("data2012.csv", index=True, header=True)
data2013.to_csv("data2013.csv", index=True, header=True)
data2014.to_csv("data2014.csv", index=True, header=True)
