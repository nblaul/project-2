# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


csvdata2015= "2015 Stack Overflow Developer Survey Responses.csv"

data2015 = pd.read_csv(csvdata2015)
# Out:
# C:\Users\Dan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,108,121,196,197,198) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data2015
# Out:
#       Unnamed: 0              Unnamed: 1              Unnamed: 2  \
# 0        Country                     Age                  Gender
# 1        Croatia                   25-29                    Male
# 2         France                   20-24                    Male
# 3          India                   20-24                    Male
# 4         Latvia                   25-29                    Male
# ...          ...                     ...                     ...
# 26082    Vietnam                   20-24                    Male
# 26083    Vietnam                   25-29                    Male
# 26084    Vietnam                   25-29                    Male
# 26085   Zimbabwe                     NaN                     NaN
# 26086   Zimbabwe  Prefer not to disclose  Prefer not to disclose
#
#            Unnamed: 3                         Unnamed: 4  \
# 0      Tabs or Spaces  Years IT / Programming Experience
# 1                Tabs                        2 - 5 years
# ...

# %%
data2015.columns = data2015.iloc[0]
data2015 = data2015.drop(0).reset_index(drop=True)
data2015
# Out:
# 0       Country                     Age                  Gender  \
# 0       Croatia                   25-29                    Male
# 1        France                   20-24                    Male
# 2         India                   20-24                    Male
# 3        Latvia                   25-29                    Male
# 4        Norway                   30-34                    Male
# ...         ...                     ...                     ...
# 26081   Vietnam                   20-24                    Male
# 26082   Vietnam                   25-29                    Male
# 26083   Vietnam                   25-29                    Male
# 26084  Zimbabwe                     NaN                     NaN
# 26085  Zimbabwe  Prefer not to disclose  Prefer not to disclose
#
# 0     Tabs or Spaces Years IT / Programming Experience  \
# 0               Tabs                       2 - 5 years
# 1             Spaces                       1 - 2 years
# ...

# %%
data2015 = data2015[['Country',
                     'Age',
                     'Compensation',
                     'Current Lang & Tech: AngularJS',
                     'Current Lang & Tech: C',
                     'Current Lang & Tech: C++',
                     'Current Lang & Tech: C++11',
                     'Current Lang & Tech: C#',
                     'Current Lang & Tech: Cassandra',
                     'Current Lang & Tech: CoffeeScript',
                     'Current Lang & Tech: Clojure',
                     'Current Lang & Tech: Dart',
                     'Current Lang & Tech: F#',
                     'Current Lang & Tech: Go',
                     'Current Lang & Tech: Haskell',
                     'Current Lang & Tech: Java',
                     'Current Lang & Tech: JavaScript',
                     'Current Lang & Tech: Matlab',
                     'Current Lang & Tech: Node.js',
                     'Current Lang & Tech: Objective-C',
                     'Current Lang & Tech: Perl',
                     'Current Lang & Tech: PHP',
                     'Current Lang & Tech: Python',
                     'Current Lang & Tech: R',
                     'Current Lang & Tech: Ruby',
                     'Current Lang & Tech: Rust',
                     'Current Lang & Tech: Scala',
                     'Current Lang & Tech: SQL',
                     'Current Lang & Tech: Swift',
                     'Current Lang & Tech: Visual Basic',
                     'Current Lang & Tech: Write-In']]
data2015
# Out:
# 0       Country                     Age        Compensation  \
# 0       Croatia                   25-29   $20,000 - $40,000
# 1        France                   20-24   $20,000 - $40,000
# 2         India                   20-24  $80,000 - $100,000
# 3        Latvia                   25-29                 NaN
# 4        Norway                   30-34   $60,000 - $80,000
# ...         ...                     ...                 ...
# 26081   Vietnam                   20-24                 NaN
# 26082   Vietnam                   25-29                 NaN
# 26083   Vietnam                   25-29                 NaN
# 26084  Zimbabwe                     NaN                 NaN
# 26085  Zimbabwe  Prefer not to disclose                 NaN
#
# 0     Current Lang & Tech: AngularJS Current Lang & Tech: C  \
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# ...

# %%
list(data2015.columns)
# Out:
# ['Country',
#  'Age',
#  'Compensation',
#  'Current Lang & Tech: AngularJS',
#  'Current Lang & Tech: C',
#  'Current Lang & Tech: C++',
#  'Current Lang & Tech: C++11',
#  'Current Lang & Tech: C#',
#  'Current Lang & Tech: Cassandra',
#  'Current Lang & Tech: CoffeeScript',
#  'Current Lang & Tech: Clojure',
#  'Current Lang & Tech: Dart',
#  'Current Lang & Tech: F#',
#  'Current Lang & Tech: Go',
#  'Current Lang & Tech: Haskell',
#  'Current Lang & Tech: Java',
#  'Current Lang & Tech: JavaScript',
#  'Current Lang & Tech: Matlab',
#  'Current Lang & Tech: Node.js',
#  'Current Lang & Tech: Objective-C',
#  'Current Lang & Tech: Perl',
#  'Current Lang & Tech: PHP',
#  'Current Lang & Tech: Python',
#  'Current Lang & Tech: R',
#  'Current Lang & Tech: Ruby',
#  'Current Lang & Tech: Rust',
#  'Current Lang & Tech: Scala',
#  'Current Lang & Tech: SQL',
#  'Current Lang & Tech: Swift',
#  'Current Lang & Tech: Visual Basic',
#  'Current Lang & Tech: Write-In']

# %%
data2015= data2015.rename(columns={'Current Lang & Tech: AngularJS':'AngularJS',
 'Current Lang & Tech: C':'C',
 'Current Lang & Tech: C++':'C++',
 'Current Lang & Tech: C++11':'C++11',
 'Current Lang & Tech: C#':'C#',
 'Current Lang & Tech: Cassandra':'Cassandra',
 'Current Lang & Tech: CoffeeScript':'CoffeeScript',
 'Current Lang & Tech: Clojure':'Clojure',
 'Current Lang & Tech: Dart':'Dart',
 'Current Lang & Tech: F#':'F#',
 'Current Lang & Tech: Go':'Go',
 'Current Lang & Tech: Haskell':'Heskell',
 'Current Lang & Tech: Java':'Java',
 'Current Lang & Tech: JavaScript':'JavaScript',
 'Current Lang & Tech: Matlab':'Matlab',
 'Current Lang & Tech: Node.js':'Node.js',
 'Current Lang & Tech: Objective-C':'Objective-c',
 'Current Lang & Tech: Perl':'Perl',
 'Current Lang & Tech: PHP':'PHP',
 'Current Lang & Tech: Python':'Python',
 'Current Lang & Tech: R':'R',
 'Current Lang & Tech: Ruby':'Ruby',
 'Current Lang & Tech: Rust':'Rust',
 'Current Lang & Tech: Scala':'Scala',
 'Current Lang & Tech: SQL':'SQL',
 'Current Lang & Tech: Swift':'Swift',
 'Current Lang & Tech: Visual Basic':'Visual BAsic',
 'Current Lang & Tech: Write-In':'Other'})

# %%
data2015
# Out:
# 0       Country                     Age        Compensation AngularJS    C  \
# 0       Croatia                   25-29   $20,000 - $40,000       NaN  NaN
# 1        France                   20-24   $20,000 - $40,000       NaN  NaN
# 2         India                   20-24  $80,000 - $100,000       NaN  NaN
# 3        Latvia                   25-29                 NaN       NaN  NaN
# 4        Norway                   30-34   $60,000 - $80,000       NaN  NaN
# ...         ...                     ...                 ...       ...  ...
# 26081   Vietnam                   20-24                 NaN       NaN  NaN
# 26082   Vietnam                   25-29                 NaN       NaN  NaN
# 26083   Vietnam                   25-29                 NaN       NaN  NaN
# 26084  Zimbabwe                     NaN                 NaN       NaN  NaN
# 26085  Zimbabwe  Prefer not to disclose                 NaN       NaN  NaN
#
# ...

# %%
list(data2015.columns)
# Out:
# ['Country',
#  'Age',
#  'Compensation',
#  'AngularJS',
#  'C',
#  'C++',
#  'C++11',
#  'C#',
#  'Cassandra',
#  'CoffeeScript',
#  'Clojure',
#  'Dart',
#  'F#',
#  'Go',
#  'Heskell',
#  'Java',
#  'JavaScript',
#  'Matlab',
#  'Node.js',
#  'Objective-c',
#  'Perl',
#  'PHP',
#  'Python',
#  'R',
#  'Ruby',
#  'Rust',
#  'Scala',
#  'SQL',
#  'Swift',
#  'Visual BAsic',
#  'Other']

# %%
languages = [ 'AngularJS',
                 'C',
                 'C++',
                 'C++11',
                 'C#',
                 'Cassandra',
                 'CoffeeScript',
                 'Clojure',
                 'Dart',
                 'F#',
                 'Go',
                 'Heskell',
                 'Java',
                 'JavaScript',
                 'Matlab',
                 'Node.js',
                 'Objective-c',
                 'Perl',
                 'PHP',
                 'Python',
                 'R',
                 'Ruby',
                 'Rust',
                 'Scala',
                 'SQL',
                 'Swift',
                 'Visual BAsic']
for lang in languages:
    data2015[lang] = (data2015[lang] == lang)

# %%
data2015
# Out:
# 0       Country                     Age        Compensation  AngularJS      C  \
# 0       Croatia                   25-29   $20,000 - $40,000      False  False
# 1        France                   20-24   $20,000 - $40,000      False  False
# 2         India                   20-24  $80,000 - $100,000      False  False
# 3        Latvia                   25-29                 NaN      False  False
# 4        Norway                   30-34   $60,000 - $80,000      False  False
# ...         ...                     ...                 ...        ...    ...
# 26081   Vietnam                   20-24                 NaN      False  False
# 26082   Vietnam                   25-29                 NaN      False  False
# 26083   Vietnam                   25-29                 NaN      False  False
# 26084  Zimbabwe                     NaN                 NaN      False  False
# 26085  Zimbabwe  Prefer not to disclose                 NaN      False  False
#
# ...

# %%
languages2015 = data2015[['AngularJS',
                             'C',
                             'C++',
                             'C++11',
                             'C#',
                             'Cassandra',
                             'CoffeeScript',
                             'Clojure',
                             'Dart',
                             'F#',
                             'Go',
                             'Heskell',
                             'Java',
                             'JavaScript',
                             'Matlab',
                             'Node.js',
                             'Objective-c',
                             'Perl',
                             'PHP',
                             'Python',
                             'R',
                             'Ruby',
                             'Rust',
                             'Scala',
                             'SQL',
                             'Swift',
                             'Visual BAsic']]
languages2015.reset_index()
languages2015 = languages2015[['AngularJS',
                             'C',
                             'C++',
                             'C++11',
                             'C#',
                             'Cassandra',
                             'CoffeeScript',
                             'Clojure',
                             'Dart',
                             'F#',
                             'Go',
                             'Heskell',
                             'Java',
                             'JavaScript',
                             'Matlab',
                             'Node.js',
                             'Objective-c',
                             'Perl',
                             'PHP',
                             'Python',
                             'R',
                             'Ruby',
                             'Rust',
                             'Scala',
                             'SQL',
                             'Swift',
                             'Visual BAsic']]
languages2015
# Out:
# 0      AngularJS      C    C++  C++11     C#  Cassandra  CoffeeScript  \
# 0          False  False  False  False  False      False         False
# 1          False  False  False  False   True      False         False
# 2          False  False  False  False   True      False         False
# 3          False  False  False  False  False      False         False
# 4          False  False  False  False   True      False         False
# ...          ...    ...    ...    ...    ...        ...           ...
# 26081      False  False  False  False  False      False         False
# 26082      False  False  False  False  False      False         False
# 26083      False  False  False  False  False      False         False
# 26084      False  False  False  False  False      False         False
# 26085      False  False  False  False  False      False         False
#
# 0      Clojure   Dart     F#  ...   Perl    PHP  Python      R   Ruby   Rust  \
# ...

# %%
languages_worked_percentages = languages2015.mean().sort_values(ascending=False) * 100
languages_worked_percentages
# Out:
# 0
# JavaScript      45.856015
# SQL             36.184160
# Java            31.507322
# C#              26.638810
# PHP             25.028751
# Python          20.079736
# C++             17.361803
# C               13.846508
# Node.js         11.189910
# AngularJS       11.166909
# C++11            7.095760
# Ruby             6.766081
# Matlab           3.296788
# CoffeeScript     3.001610
# Swift            2.909607
# R                2.894273
# Perl             2.829104
# Scala            2.062409
# Go               1.771065
# Cassandra        0.774362
# Clojure          0.674691
# F#               0.667024
# Dart             0.417849
# Rust             0.394848
# Heskell          0.000000
# Objective-c      0.000000
# Visual BAsic     0.000000
# dtype: float64

# %%
pct_df = pd.DataFrame(languages_worked_percentages)
pct_df.head()
# Out:
#                     0
# 0
# JavaScript  45.856015
# SQL         36.184160
# Java        31.507322
# C#          26.638810
# PHP         25.028751

# %%
pct_df.columns
# this is weird
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
list(pct_df.columns)
# Out:
# [0]

# %%
pct_df.columns = ["percent"]
pct_df
# Out:
#                 percent
# 0
# JavaScript    45.856015
# SQL           36.184160
# Java          31.507322
# C#            26.638810
# PHP           25.028751
# Python        20.079736
# C++           17.361803
# C             13.846508
# Node.js       11.189910
# AngularJS     11.166909
# C++11          7.095760
# Ruby           6.766081
# Matlab         3.296788
# CoffeeScript   3.001610
# Swift          2.909607
# R              2.894273
# Perl           2.829104
# Scala          2.062409
# Go             1.771065
# Cassandra      0.774362
# Clojure        0.674691
# F#             0.667024
# Dart           0.417849
# Rust           0.394848
# Heskell        0.000000
# Objective-c    0.000000
# Visual BAsic   0.000000

# %%
pct_df.columns
# Out:
# Index(['percent'], dtype='object')

# %%
list(pct_df.columns)
# Out:
# ['percent']

# %%
pct_df.reset_index(inplace=True)

# %%
pct_df.columns = ["language", "percent"]

# %%
pct_df
# Out:
#         language    percent
# 0     JavaScript  45.856015
# 1            SQL  36.184160
# 2           Java  31.507322
# 3             C#  26.638810
# 4            PHP  25.028751
# 5         Python  20.079736
# 6            C++  17.361803
# 7              C  13.846508
# 8        Node.js  11.189910
# 9      AngularJS  11.166909
# 10         C++11   7.095760
# 11          Ruby   6.766081
# 12        Matlab   3.296788
# 13  CoffeeScript   3.001610
# 14         Swift   2.909607
# 15             R   2.894273
# 16          Perl   2.829104
# 17         Scala   2.062409
# 18            Go   1.771065
# 19     Cassandra   0.774362
# 20       Clojure   0.674691
# 21            F#   0.667024
# 22          Dart   0.417849
# 23          Rust   0.394848
# 24       Heskell   0.000000
# 25   Objective-c   0.000000
# 26  Visual BAsic   0.000000

# %%
pct_df.to_csv("language_percent_2015.csv", index=True, header=True)

# %%
data2015
# Out:
# 0       Country                     Age        Compensation  AngularJS      C  \
# 0       Croatia                   25-29   $20,000 - $40,000      False  False
# 1        France                   20-24   $20,000 - $40,000      False  False
# 2         India                   20-24  $80,000 - $100,000      False  False
# 3        Latvia                   25-29                 NaN      False  False
# 4        Norway                   30-34   $60,000 - $80,000      False  False
# ...         ...                     ...                 ...        ...    ...
# 26081   Vietnam                   20-24                 NaN      False  False
# 26082   Vietnam                   25-29                 NaN      False  False
# 26083   Vietnam                   25-29                 NaN      False  False
# 26084  Zimbabwe                     NaN                 NaN      False  False
# 26085  Zimbabwe  Prefer not to disclose                 NaN      False  False
#
# ...

# %%
data2015['Year'] = "2015"
data2015
# Out:
# 0       Country                     Age        Compensation  AngularJS      C  \
# 0       Croatia                   25-29   $20,000 - $40,000      False  False
# 1        France                   20-24   $20,000 - $40,000      False  False
# 2         India                   20-24  $80,000 - $100,000      False  False
# 3        Latvia                   25-29                 NaN      False  False
# 4        Norway                   30-34   $60,000 - $80,000      False  False
# ...         ...                     ...                 ...        ...    ...
# 26081   Vietnam                   20-24                 NaN      False  False
# 26082   Vietnam                   25-29                 NaN      False  False
# 26083   Vietnam                   25-29                 NaN      False  False
# 26084  Zimbabwe                     NaN                 NaN      False  False
# 26085  Zimbabwe  Prefer not to disclose                 NaN      False  False
#
# ...

# %%
data2015.to_csv("cleandata2015.csv", index=True, header=True)
